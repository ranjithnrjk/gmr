# %%
import pandas as pd

# %%
df_isp_irc = pd.read_excel('vt_isp_irc.xlsx')
df_isp_task = pd.read_excel('vt_isp_task_mhrs.xlsx')
df_isp_material = pd.read_excel('vt_isp_material_consumption_pricing.xlsx')

df_isq_irc = pd.read_excel('vt_isq_irc.xlsx')
df_isq_task = pd.read_excel('vt_isq_task_mhrs.xlsx')
df_isq_material = pd.read_excel('vt_isq_material_consumption_pricing.xlsx')

df_iux_irc = pd.read_excel('vt_iux_irc.xlsx')
df_iux_task = pd.read_excel('vt_iux_task_mhrs.xlsx')
df_iux_material = pd.read_excel('vt_iux_material_consumption_pricing.xlsx')

# %%
df_isp_irc.head()
# Out:
#   DeleteFlag   Type           Log Item #  ATA #  \
# 0         No  MIREP  HMV23/000059/0923/1     53
# 1         No  MIREP  HMV23/000059/0923/2     34
# 2         No  MIREP  HMV23/000059/0923/3     23
# 3         No  MIREP  HMV23/000059/0923/4     53
# 4         No  MIREP  HMV23/000059/0923/5     53
#
#                                          Description  \
# 0  1. DURING INSPECTION OBERVED LH WING SLATE #01...
# 1  DURING ARRIVAL INSPECTION CHECK FOUND FAILURE ...
# 2  DURING ARRIVAL INSPECTION FOUND STATIC DISCHAR...
# 3  DURING ARRIVAL CHECK FOUND SERVICE LIGHT LAMP ...
# 4  DURING ARRIVAL INSPECTION , OBSERVED FOLLOWINS...
#
#                                    Corrective Action        Discrepancy #  \
# 0  1. CARRIED OUT INSTALLATION OF LH WING SLAT #0...  HMV23/000059/0923/1
# 1  CARRIED OUT TROUBLESHOOTING IAW TSM TASK 31-32...  HMV23/000059/0923/2
# 2  STATIC DISCHARGERS REPLACED AT FOLLOWING LOCAT...  HMV23/000059/0923/3
# 3  1. CARRIED OUT REPLACEMENT OF SERVICE LIGHT LA...  HMV23/000059/0923/4
# 4  1) RH SIDE WING NO#1 SLAT, NO.3 TRACK SQURE SE...  HMV23/000059/0923/5
#
#   Action  Status       Source Task/Discrep. #  ...  Deferral FC  \
# 0  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
# 1  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
# 2  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
# 3  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
# 4  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
#
#   Deferral Parameter Deferral Value Deferral Calendar Value Deferral Calendar  \
# 0                NaN            NaN                     NaN             Hours
# 1                NaN            NaN                     NaN             Hours
# 2                NaN            NaN                     NaN             Hours
# 3                NaN            NaN                     NaN             Hours
# 4                NaN            NaN                     NaN             Hours
#
#   Deferral Item # Deferral Type Reason for Deferral Auth. Ref. #  \
# 0             NaN           NaN                 NaN          NaN
# 1             NaN           NaN                 NaN          NaN
# 2             NaN           NaN                 NaN          NaN
# 3             NaN           NaN                 NaN          NaN
# 4             NaN           NaN                 NaN          NaN
#
#   Message Center
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Fields to consider in 'VT ISP IRC'
# - Planned Start Date
# - Planned End Date
# - Actual Start Date
# - Actual End Date
# - Est. Man Hrs.
# - Actual Man Hrs.
# - Insp Req?
# - Mech Req?
# - Part Required?
# - Contract Classification
# - Source Task/Discrep. #
# - Description
# - Corrective Action
# - Log Item #

# %%
df_isp_irc = df_isp_irc[['Planned Start Date',
'Planned End Date',
'Actual Start Date',
'Actual End Date',
'Est. Man Hrs.',
'Actual Man Hrs.',
'Insp Req?',
'Mech Req?',
'Part Required?',
'Contract Classification',
'Source Task/Discrep. #',
'Description',
'Corrective Action',
'Log Item #']].copy()

# %%
df_isp_irc[['Description']].iloc[:3].values
# Out:
# array([['1. DURING INSPECTION OBERVED LH WING SLATE #01, TRACK#02 ,#03, #04 UPPER BULB SEAL DAMAGE.SAME TO BE REPLACED.\n\n2. DURING INSPECTION OBSERVED SLAT#02 TRACK #5 PLATE DAMAGE.SAME TO BE REPLACED.'],
#        ['DURING ARRIVAL INSPECTION CHECK FOUND FAILURE MESSAGE IN PFR " NO ADF 1 DATA (INTM) ".'],
#        ['DURING ARRIVAL INSPECTION FOUND STATIC DISCHARGERS DAMAGED AT LOCATION : \n1) LH HORZ STAB TYPE A DISCHARGER QTY# 2 & TYPE B DISCHARGER QTY#3 \n2) RH HORZ STAB TYPE A DISCHARGER QTY#1 \n3)VERTICAL STABILISER TYPE A DISCHARGER QTY 01 & TYPE B DISCHARGER QTY 02.']],
#       dtype=object)

# %%
df_isq_irc.head()
# Out:
#   DeleteFlag   Type           Log Item #  ATA #  \
# 0         No  MIREP  HMV23/000055/0923/1     57
# 1         No  MIREP  HMV23/000055/0923/2     53
# 2         No  MIREP  HMV23/000055/0923/3     22
# 3         No  MIREP  HMV23/000055/0923/4     34
# 4         No  MIREP  HMV23/000055/0923/5     38
#
#                                          Description  \
# 0  DURING ARRIVAL INSPECTION , OBSERVED DENT ON S...
# 1  DURING INSPECTION OBSERVED LH WING SLAT#5 WEAT...
# 2  DURING ARRIVAL INSPECTION FOUND FOLLOWING WARN...
# 3  DURING ARRIVAL INSPECTION FOUND FOLLOWING FAIL...
# 4  DURING ARRIVAL INSPECTION FOUND FOLLOWING FAIL...
#
#                                    Corrective Action        Discrepancy #  \
# 0  REFER SDIRC HMV23/000055/0923/7 FOR REPAIR DET...  HMV23/000055/0923/1
# 1  CARRIED OUT INSTALLATION OF LH WING SLAT #5 OU...  HMV23/000055/0923/2
# 2  NO FAILURE MSG RELATED TO WARNING MSG FOUND IN...  HMV23/000055/0923/3
# 3  T/S CARRIED OUT AS PER TSM 34-53-00-810-801-A ...  HMV23/000055/0923/4
# 4  CARRIED OUT TROUBLESHOOTING IAW TSM 38-31-00-8...  HMV23/000055/0923/5
#
#   Action  Status       Source Task/Discrep. #  ...  Deferral FC  \
# 0  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
# 1  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
# 2  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
# 3  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
# 4  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
#
#   Deferral Parameter Deferral Value Deferral Calendar Value Deferral Calendar  \
# 0                NaN            NaN                     NaN             Hours
# 1                NaN            NaN                     NaN             Hours
# 2                NaN            NaN                     NaN             Hours
# 3                NaN            NaN                     NaN             Hours
# 4                NaN            NaN                     NaN             Hours
#
#   Deferral Item # Deferral Type Reason for Deferral Auth. Ref. #  \
# 0             NaN           NaN                 NaN          NaN
# 1             NaN           NaN                 NaN          NaN
# 2             NaN           NaN                 NaN          NaN
# 3             NaN           NaN                 NaN          NaN
# 4             NaN           NaN                 NaN          NaN
#
#   Message Center
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 66 columns]

# %%
df_iux_irc.head()
# Out:
#   DeleteFlag   Type           Log Item #  ATA #  \
# 0         No  MIREP  HMV23/000043/0823/1     33
# 1         No  MIREP  HMV23/000043/0823/2     25
# 2         No  MIREP  HMV23/000043/0823/3     53
# 3         No  MIREP  HMV23/000043/0823/4     20
# 4         No  MIREP  HMV23/000043/0823/5     53
#
#                                          Description  \
# 0  DURING ARRIVAL INSPECTION OBSERVED \n1. RH NAV...
# 1  CARRY OUT CA SEATS AND DOOR TRIMS (QTY49) PAIN...
# 2  DURING ARRIVAL INSPECTION OBSERVED DELAMINATIO...
# 3  DURING PHYSICAL INSPECTION OF BONDING LEADS, O...
# 4  DURING ARRIVAL INSPECTION OBSERVED DELAMINATIO...
#
#                                    Corrective Action        Discrepancy #  \
# 0  1. RH NAV POSITION LIGHT TROUBLESHOOTING CARRI...  HMV23/000043/0823/1
# 1  1.FWD AND AFT WALL MOUNTED CABIN ATTENDENT SEA...  HMV23/000043/0823/2
# 2  1)REMOVED FWD CARGO FLOOR PANEL 131AF,131EF,13...  HMV23/000043/0823/3
# 3  BONDING JUMPERS AT FOLLOWING LOCATIONS REPLACE...  HMV23/000043/0823/4
# 4  1)REMOVED AFT CARGO FLOOR PANELS 151SG,151DF,1...  HMV23/000043/0823/5
#
#   Action  Status       Source Task/Discrep. #  ...  Deferral FC  \
# 0  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
# 1  Close  Closed            AWR23/002577/0823  ...          NaN
# 2  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
# 3  Close  Closed   WEAR LIMITS- BONDING LEADS  ...          NaN
# 4  Close  Closed  AIRCRAFT ARRIVAL INSPECTION  ...          NaN
#
#   Deferral Parameter Deferral Value Deferral Calendar Value Deferral Calendar  \
# 0                NaN            NaN                     NaN             Hours
# 1                NaN            NaN                     NaN             Hours
# 2                NaN            NaN                     NaN             Hours
# 3                NaN            NaN                     NaN             Hours
# 4                NaN            NaN                     NaN             Hours
#
#   Deferral Item # Deferral Type Reason for Deferral Auth. Ref. #  \
# 0             NaN           NaN                 NaN          NaN
# 1             NaN           NaN                 NaN          NaN
# 2             NaN           NaN                 NaN          NaN
# 3             NaN           NaN                 NaN          NaN
# 4             NaN           NaN                 NaN          NaN
#
#   Message Center
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Tokenize and embed the descriptions of unexpected observations made.

# %%
text_data = df_isp_irc['Description'].tolist()+df_isq_irc['Description'].tolist()+df_iux_irc['Description'].tolist()

# %%
from nltk.tokenizeenize import
